# %%
import os

# Path to the main directory
main_dir = './sample_data/songs_mood_wise'

# List to store counts of files in each folder
mood_counts = {}

# Loop through each folder (subdirectory) in the main directory
for mood_folder in os.listdir(main_dir):
    mood_path = os.path.join(main_dir, mood_folder)

    # Check if it's a directory
    if os.path.isdir(mood_path):
        # Count the number of files in the directory
        file_count = len([file for file in os.listdir(mood_path) if os.path.isfile(os.path.join(mood_path, file))])
        mood_counts[mood_folder] = file_count

# Display the count of files in each folder
for mood, count in mood_counts.items():
    print(f"{mood}: {count} files")
# Out:
# anxiety: 56 files
# contentment: 56 files
# exuberance: 58 files
# .ipynb_checkpoints: 0 files
# depression: 55 files

# %%
#gpu ram clearing
import torch
torch.cuda.empty_cache()

# %%
#system ram clearing
import gc
gc.collect()
import torch
import torch.nn.functional as F
from keras.models import Sequential

# %%
# !pip install transformers torchaudio librosa pandas
import gc
import os
import torch
import torchaudio
import pandas as pd
from transformers import AutoModel, AutoTokenizer
from transformers import Wav2Vec2FeatureExtractor
from transformers import Wav2Vec2ForCTC
import librosa
import numpy as np

# Set your Hugging Face API token
os.environ['HF_TOKEN'] = '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'  # Replace with your actual HF token

# Check if a GPU is available and set the device accordingly
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if device.type == "cuda":
    print("GPU is available and will be used.")
else:
    print("GPU is not available; using CPU.")

# loading our model weights
model = AutoModel.from_pretrained("m-a-p/MERT-v1-330M", trust_remote_code=True)
# loading the corresponding preprocessor config
processor = Wav2Vec2FeatureExtractor.from_pretrained("m-a-p/MERT-v1-330M",trust_remote_code=True)

 #Move the model to the device (GPU if available)
model = model.to(device)
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (2.4.1+cu121)
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (0.10.2.post1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: torch==2.4.1 in /usr/local/lib/python3.10/dist-packages (from torchaudio) (2.4.1+cu121)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.4.1->torchaudio) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.4.1->torchaudio) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.4.1->torchaudio) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.4.1->torchaudio) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.4.1->torchaudio) (2024.6.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.5.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.60.0)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.0.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.1->librosa) (4.3.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.1->librosa) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.4.1->torchaudio) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.4.1->torchaudio) (1.3.0)
# GPU is available and will be used.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# WARNING: feature_extractor_cqt requires the libray 'nnAudio'
# Some weights of the model checkpoint at m-a-p/MERT-v1-330M were not used when initializing MERTModel: ['encoder.pos_conv_embed.conv.weight_g', 'encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing MERTModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing MERTModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of MERTModel were not initialized from the model checkpoint at m-a-p/MERT-v1-330M and are newly initialized: ['encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'encoder.pos_conv_embed.conv.parametrizations.weight.original1']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense
import ast # Import the ast module

# Function to process audio, adjust its length to 5 minutes, extract MERT features, and flatten them
def process_audio_and_extract_features(audio_path, label_tensor, df):
    # Load the audio file
    waveform, sample_rate = torchaudio.load(audio_path)
    torch.cuda.empty_cache()
    gc.collect()

    # Check if the sampling rate is 24kHz
    if sample_rate != 24000:
        print(f"Resampling from {sample_rate}Hz to 24000Hz for {audio_path}")
        waveform = torchaudio.transforms.Resample(orig_freq=sample_rate, new_freq=24000)(waveform)
    else:
        print(f"Audio already in 24kHz for {audio_path}")

    # Ensure waveform is mono by averaging channels if needed
    if waveform.shape[0] > 1:
        waveform = waveform.mean(dim=0, keepdim=True)

    # Determine the required length for 5 minutes in samples
    target_samples = 300 * 24000  # 5 minutes * 16000 samples per second

    # Truncate or pad waveform to make it exactly 5 minutes
    num_samples = waveform.shape[1]
    if num_samples > target_samples:
        waveform = waveform[:, :target_samples]  # Truncate to 5 minutes
    elif num_samples < target_samples:
        padding = target_samples - num_samples
        waveform = torch.nn.functional.pad(waveform, (0, padding))  # Pad to 5 minutes

    print(f"Adjusted waveform shape: {waveform.shape}")

    # Move waveform to the device (GPU if available)
    waveform = waveform.to(device)

    # Extract MERT features
    with torch.no_grad():
        mert_features = None  # Initialize to avoid UnboundLocalError
        try:
            outputs = model(waveform)
            mert_features = outputs.last_hidden_state.squeeze().to(device)
            print(mert_features.shape)
            # Apply average pooling on the features
            # Assuming mert_features has shape [22499, 1024]
            # Reshape to (batch_size, channels, length)
            mert_features_reshaped = mert_features.permute(1, 0).unsqueeze(0)  # Shape: [1, 1024, 22499]
            # Define a new window size based on your requirements (e.g., pooling every 10 seconds)
            window_size = 749  # Adjust this as needed

            # Apply average pooling along the time dimension (length)
            pooled_features = F.avg_pool1d(mert_features_reshaped, kernel_size=window_size, stride=window_size)

            # Remove the unnecessary dimensions (if needed)
            pooled_features = pooled_features.squeeze(0).permute(1, 0)  # Shape: [num_pooled_windows, 1024]


            print(pooled_features.shape)
            # Convert mert_features and label to list formats for the DataFrame
            mert_features_list = pooled_features.tolist()
            rows = len(mert_features_list)
            columns = len(mert_features_list[0]) if rows > 0 else 0  # Check for empty lists
            print("Shape:", (rows, columns))  # Output: (3, 3)
            mood_label = label_tensor.item()  # Extract scalar from label tensor

            # Create a new DataFrame row and append it
            new_row = pd.DataFrame({
                'mert_feature_vector': [mert_features_list],
                'mood': [mood_label]
            })
            df = pd.concat([df, new_row], ignore_index=True)

        except RuntimeError as e:
            print("RuntimeError:", e)
            if "CUDA out of memory" in str(e):
                print("Out of memory error. Try reducing the input size or batch size.")
                return None

    print(f"MERT features shape for {audio_path}: {mert_features.shape}")
    torch.cuda.empty_cache()
    return df

# Directory structure and DataFrame setup
audio_dir = './sample_data/songs_mood_wise'  # Replace with your audio files directory
emotion_labels = ['anxiety','exuberance','depression','contentment']  # Define your emotions
label_to_index = {'anxiety': 0, 'exuberance': 1, 'depression': 2, 'contentment': 3}
df = pd.DataFrame(columns=['mert_feature_vector', 'mood'])  # Initialize DataFrame

counter=0
# Process each song, extract features, and add them to the DataFrame
for label in emotion_labels:
    label_dir = os.path.join(audio_dir, label)
    print(f"Processing label directory: {label_dir}")
    for filename in os.listdir(label_dir):
        if filename.endswith('.mp3'):  # Adjust for your file format
            audio_path = os.path.join(label_dir, filename)
            label_tensor = torch.tensor([label_to_index[label]], dtype=torch.float32).to(device)

            # Process and extract MERT features, updating the DataFrame
            df = process_audio_and_extract_features(audio_path, label_tensor, df)
            print(f"Adding features for {filename} with label {label}")
            print(f"Processed file: {filename}")
            counter+=1
            print(counter)

print("Final DataFrame:")
print(df.head())

# Assuming df is your DataFrame that you've been working with
print(df.tail(5))  # Optionally, print the last 5 rows to inspect the data
print("Shape of the DataFrame:", df.shape)

# Check if DataFrame is empty
if df.empty:
    print("Error: DataFrame is empty. No data to save.")
else:
    # If the DataFrame has data, append to CSV or create a new one
    csv_file = './final mert_song_features_for 750 window size.csv'

    if os.path.exists(csv_file):
        df.to_csv(csv_file, mode='a', header=False, index=False)  # Append without header
        print("Data appended to existing CSV.")
    else:
        df.to_csv(csv_file, mode='w', header=True, index=False)  # Write with header
        print("DataFrame saved as new CSV.")

    print("DataFrame saved successfully.")
# Out:
# Processing label directory: ./sample_data/songs_mood_wise/anxiety
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Chinna-Thangam.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Chinna-Thangam.mp3: torch.Size([22499, 1024])
# Adding features for Chinna-Thangam.mp3 with label anxiety
# Processed file: Chinna-Thangam.mp3
# 1
# <ipython-input-5-66c690c94280>:76: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, new_row], ignore_index=True)
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Maguva Maguva (Female Version).mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Maguva Maguva (Female Version).mp3: torch.Size([22499, 1024])
# Adding features for Maguva Maguva (Female Version).mp3 with label anxiety
# Processed file: Maguva Maguva (Female Version).mp3
# 2
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Puthumazhayayi.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Puthumazhayayi.mp3: torch.Size([22499, 1024])
# Adding features for Puthumazhayayi.mp3 with label anxiety
# Processed file: Puthumazhayayi.mp3
# 3
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Pogum-Paadhai.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Pogum-Paadhai.mp3: torch.Size([22499, 1024])
# Adding features for Pogum-Paadhai.mp3 with label anxiety
# Processed file: Pogum-Paadhai.mp3
# 4
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Kodi-Parakkudha.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Kodi-Parakkudha.mp3: torch.Size([22499, 1024])
# Adding features for Kodi-Parakkudha.mp3 with label anxiety
# Processed file: Kodi-Parakkudha.mp3
# 5
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Engengo-Kaalgal-Sellum.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Engengo-Kaalgal-Sellum.mp3: torch.Size([22499, 1024])
# Adding features for Engengo-Kaalgal-Sellum.mp3 with label anxiety
# Processed file: Engengo-Kaalgal-Sellum.mp3
# 6
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Penninu-Chilambunde-Manjari-Sayanora.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Penninu-Chilambunde-Manjari-Sayanora.mp3: torch.Size([22499, 1024])
# Adding features for Penninu-Chilambunde-Manjari-Sayanora.mp3 with label anxiety
# Processed file: Penninu-Chilambunde-Manjari-Sayanora.mp3
# 7
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Idhu-Varai.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Idhu-Varai.mp3: torch.Size([22499, 1024])
# Adding features for Idhu-Varai.mp3 with label anxiety
# Processed file: Idhu-Varai.mp3
# 8
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Pengal-Yendral.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Pengal-Yendral.mp3: torch.Size([22499, 1024])
# Adding features for Pengal-Yendral.mp3 with label anxiety
# Processed file: Pengal-Yendral.mp3
# 9
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Po Ve Po.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Po Ve Po.mp3: torch.Size([22499, 1024])
# Adding features for Po Ve Po.mp3 with label anxiety
# Processed file: Po Ve Po.mp3
# 10
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Angakale-.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Angakale-.mp3: torch.Size([22499, 1024])
# Adding features for Angakale-.mp3 with label anxiety
# Processed file: Angakale-.mp3
# 11
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Thallumaala Paattu.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Thallumaala Paattu.mp3: torch.Size([22499, 1024])
# Adding features for Thallumaala Paattu.mp3 with label anxiety
# Processed file: Thallumaala Paattu.mp3
# 12
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Raa-Raa-Sarasaku.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Raa-Raa-Sarasaku.mp3: torch.Size([22499, 1024])
# Adding features for Raa-Raa-Sarasaku.mp3 with label anxiety
# Processed file: Raa-Raa-Sarasaku.mp3
# 13
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Enna-Solla-Pogirai.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Enna-Solla-Pogirai.mp3: torch.Size([22499, 1024])
# Adding features for Enna-Solla-Pogirai.mp3 with label anxiety
# Processed file: Enna-Solla-Pogirai.mp3
# 14
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Naalo Neeku.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Naalo Neeku.mp3: torch.Size([22499, 1024])
# Adding features for Naalo Neeku.mp3 with label anxiety
# Processed file: Naalo Neeku.mp3
# 15
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Oh Prema.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Oh Prema.mp3: torch.Size([22499, 1024])
# Adding features for Oh Prema.mp3 with label anxiety
# Processed file: Oh Prema.mp3
# 16
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Premisthunna.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Premisthunna.mp3: torch.Size([22499, 1024])
# Adding features for Premisthunna.mp3 with label anxiety
# Processed file: Premisthunna.mp3
# 17
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Veyil Chilla.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Veyil Chilla.mp3: torch.Size([22499, 1024])
# Adding features for Veyil Chilla.mp3 with label anxiety
# Processed file: Veyil Chilla.mp3
# 18
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Swararaagamai Kilivaathilil.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Swararaagamai Kilivaathilil.mp3: torch.Size([22499, 1024])
# Adding features for Swararaagamai Kilivaathilil.mp3 with label anxiety
# Processed file: Swararaagamai Kilivaathilil.mp3
# 19
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Cheliya Cheliya.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Cheliya Cheliya.mp3: torch.Size([22499, 1024])
# Adding features for Cheliya Cheliya.mp3 with label anxiety
# Processed file: Cheliya Cheliya.mp3
# 20
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/This-Is-It-Theme.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/This-Is-It-Theme.mp3: torch.Size([22499, 1024])
# Adding features for This-Is-It-Theme.mp3 with label anxiety
# Processed file: This-Is-It-Theme.mp3
# 21
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Mudhal-Murai.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Mudhal-Murai.mp3: torch.Size([22499, 1024])
# Adding features for Mudhal-Murai.mp3 with label anxiety
# Processed file: Mudhal-Murai.mp3
# 22
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Solo _ Aigiri Nandini.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Solo _ Aigiri Nandini.mp3: torch.Size([22499, 1024])
# Adding features for Solo _ Aigiri Nandini.mp3 with label anxiety
# Processed file: Solo _ Aigiri Nandini.mp3
# 23
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Ninnele.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Ninnele.mp3: torch.Size([22499, 1024])
# Adding features for Ninnele.mp3 with label anxiety
# Processed file: Ninnele.mp3
# 24
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Jacobinte Swargarajyam _ Ennilerinju.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Jacobinte Swargarajyam _ Ennilerinju.mp3: torch.Size([22499, 1024])
# Adding features for Jacobinte Swargarajyam _ Ennilerinju.mp3 with label anxiety
# Processed file: Jacobinte Swargarajyam _ Ennilerinju.mp3
# 25
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Hara-Hara-Mahadevaki.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Hara-Hara-Mahadevaki.mp3: torch.Size([22499, 1024])
# Adding features for Hara-Hara-Mahadevaki.mp3 with label anxiety
# Processed file: Hara-Hara-Mahadevaki.mp3
# 26
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Yemaiundacho.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Yemaiundacho.mp3: torch.Size([22499, 1024])
# Adding features for Yemaiundacho.mp3 with label anxiety
# Processed file: Yemaiundacho.mp3
# 27
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Pranamlo Pranamga.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Pranamlo Pranamga.mp3: torch.Size([22499, 1024])
# Adding features for Pranamlo Pranamga.mp3 with label anxiety
# Processed file: Pranamlo Pranamga.mp3
# 28
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Koodara-Koottil--Duet-Version--Yesudas-Chithra.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Koodara-Koottil--Duet-Version--Yesudas-Chithra.mp3: torch.Size([22499, 1024])
# Adding features for Koodara-Koottil--Duet-Version--Yesudas-Chithra.mp3 with label anxiety
# Processed file: Koodara-Koottil--Duet-Version--Yesudas-Chithra.mp3
# 29
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Palnilavinum.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Palnilavinum.mp3: torch.Size([22499, 1024])
# Adding features for Palnilavinum.mp3 with label anxiety
# Processed file: Palnilavinum.mp3
# 30
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Karige Loga.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Karige Loga.mp3: torch.Size([22499, 1024])
# Adding features for Karige Loga.mp3 with label anxiety
# Processed file: Karige Loga.mp3
# 31
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Hey Badhulu Cheppavey.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Hey Badhulu Cheppavey.mp3: torch.Size([22499, 1024])
# Adding features for Hey Badhulu Cheppavey.mp3 with label anxiety
# Processed file: Hey Badhulu Cheppavey.mp3
# 32
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Nizhalaay Nilaavaay Rvilozhukum.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Nizhalaay Nilaavaay Rvilozhukum.mp3: torch.Size([22499, 1024])
# Adding features for Nizhalaay Nilaavaay Rvilozhukum.mp3 with label anxiety
# Processed file: Nizhalaay Nilaavaay Rvilozhukum.mp3
# 33
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Kalippu _ Premam.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Kalippu _ Premam.mp3: torch.Size([22499, 1024])
# Adding features for Kalippu _ Premam.mp3 with label anxiety
# Processed file: Kalippu _ Premam.mp3
# 34
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Badulu Tochani.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Badulu Tochani.mp3: torch.Size([22499, 1024])
# Adding features for Badulu Tochani.mp3 with label anxiety
# Processed file: Badulu Tochani.mp3
# 35
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Chinna-Thayaval.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Chinna-Thayaval.mp3: torch.Size([22499, 1024])
# Adding features for Chinna-Thayaval.mp3 with label anxiety
# Processed file: Chinna-Thayaval.mp3
# 36
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Jagame Maayaa.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Jagame Maayaa.mp3: torch.Size([22499, 1024])
# Adding features for Jagame Maayaa.mp3 with label anxiety
# Processed file: Jagame Maayaa.mp3
# 37
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Janma Methithira.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Janma Methithira.mp3: torch.Size([22499, 1024])
# Adding features for Janma Methithira.mp3 with label anxiety
# Processed file: Janma Methithira.mp3
# 38
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/antha branthiyena.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/antha branthiyena.mp3: torch.Size([22499, 1024])
# Adding features for antha branthiyena.mp3 with label anxiety
# Processed file: antha branthiyena.mp3
# 39
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/The Hymn Of Dharma.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/The Hymn Of Dharma.mp3: torch.Size([22499, 1024])
# Adding features for The Hymn Of Dharma.mp3 with label anxiety
# Processed file: The Hymn Of Dharma.mp3
# 40
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Sakkarai-Nilave.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Sakkarai-Nilave.mp3: torch.Size([22499, 1024])
# Adding features for Sakkarai-Nilave.mp3 with label anxiety
# Processed file: Sakkarai-Nilave.mp3
# 41
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Aadhiyusha-Sandhya.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Aadhiyusha-Sandhya.mp3: torch.Size([22499, 1024])
# Adding features for Aadhiyusha-Sandhya.mp3 with label anxiety
# Processed file: Aadhiyusha-Sandhya.mp3
# 42
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Atu Itu.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Atu Itu.mp3: torch.Size([22499, 1024])
# Adding features for Atu Itu.mp3 with label anxiety
# Processed file: Atu Itu.mp3
# 43
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Porkkalam-Tamil-Rap.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Porkkalam-Tamil-Rap.mp3: torch.Size([22499, 1024])
# Adding features for Porkkalam-Tamil-Rap.mp3 with label anxiety
# Processed file: Porkkalam-Tamil-Rap.mp3
# 44
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Thalapathy-Thalapathy.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Thalapathy-Thalapathy.mp3: torch.Size([22499, 1024])
# Adding features for Thalapathy-Thalapathy.mp3 with label anxiety
# Processed file: Thalapathy-Thalapathy.mp3
# 45
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Mirutha-Mirutha.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Mirutha-Mirutha.mp3: torch.Size([22499, 1024])
# Adding features for Mirutha-Mirutha.mp3 with label anxiety
# Processed file: Mirutha-Mirutha.mp3
# 46
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Sandi-Muni.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Sandi-Muni.mp3: torch.Size([22499, 1024])
# Adding features for Sandi-Muni.mp3 with label anxiety
# Processed file: Sandi-Muni.mp3
# 47
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Oru-Naalil-Yuvan-Shankar-Raja.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Oru-Naalil-Yuvan-Shankar-Raja.mp3: torch.Size([22499, 1024])
# Adding features for Oru-Naalil-Yuvan-Shankar-Raja.mp3 with label anxiety
# Processed file: Oru-Naalil-Yuvan-Shankar-Raja.mp3
# 48
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Kalippu-Katta-Kalippu-Arunraja-Kamaraj-Manikandan-Ayyappa.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Kalippu-Katta-Kalippu-Arunraja-Kamaraj-Manikandan-Ayyappa.mp3: torch.Size([22499, 1024])
# Adding features for Kalippu-Katta-Kalippu-Arunraja-Kamaraj-Manikandan-Ayyappa.mp3 with label anxiety
# Processed file: Kalippu-Katta-Kalippu-Arunraja-Kamaraj-Manikandan-Ayyappa.mp3
# 49
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Neeya-Pesiyathu.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Neeya-Pesiyathu.mp3: torch.Size([22499, 1024])
# Adding features for Neeya-Pesiyathu.mp3 with label anxiety
# Processed file: Neeya-Pesiyathu.mp3
# 50
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/O Sayonara Sayonara.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/O Sayonara Sayonara.mp3: torch.Size([22499, 1024])
# Adding features for O Sayonara Sayonara.mp3 with label anxiety
# Processed file: O Sayonara Sayonara.mp3
# 51
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Vishwaroopam.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Vishwaroopam.mp3: torch.Size([22499, 1024])
# Adding features for Vishwaroopam.mp3 with label anxiety
# Processed file: Vishwaroopam.mp3
# 52
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Ezra_thambiran song.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Ezra_thambiran song.mp3: torch.Size([22499, 1024])
# Adding features for Ezra_thambiran song.mp3 with label anxiety
# Processed file: Ezra_thambiran song.mp3
# 53
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Kadhal-Vandhum.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Kadhal-Vandhum.mp3: torch.Size([22499, 1024])
# Adding features for Kadhal-Vandhum.mp3 with label anxiety
# Processed file: Kadhal-Vandhum.mp3
# 54
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Oopirage.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Oopirage.mp3: torch.Size([22499, 1024])
# Adding features for Oopirage.mp3 with label anxiety
# Processed file: Oopirage.mp3
# 55
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/anxiety/Manasa-Manninchavamma-Karthik.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/anxiety/Manasa-Manninchavamma-Karthik.mp3: torch.Size([22499, 1024])
# Adding features for Manasa-Manninchavamma-Karthik.mp3 with label anxiety
# Processed file: Manasa-Manninchavamma-Karthik.mp3
# 56
# Processing label directory: ./sample_data/songs_mood_wise/exuberance
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Hayyoda-MassTamilan.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Hayyoda-MassTamilan.mp3: torch.Size([22499, 1024])
# Adding features for Hayyoda-MassTamilan.mp3 with label exuberance
# Processed file: Hayyoda-MassTamilan.mp3
# 57
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Chumma-Kizhi-MassTamilan.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Chumma-Kizhi-MassTamilan.mp3: torch.Size([22499, 1024])
# Adding features for Chumma-Kizhi-MassTamilan.mp3 with label exuberance
# Processed file: Chumma-Kizhi-MassTamilan.mp3
# 58
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Bhoochadae.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Bhoochadae.mp3: torch.Size([22499, 1024])
# Adding features for Bhoochadae.mp3 with label exuberance
# Processed file: Bhoochadae.mp3
# 59
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Illuminati_Aavesham.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Illuminati_Aavesham.mp3: torch.Size([22499, 1024])
# Adding features for Illuminati_Aavesham.mp3 with label exuberance
# Processed file: Illuminati_Aavesham.mp3
# 60
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Nattu-Saraku.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Nattu-Saraku.mp3: torch.Size([22499, 1024])
# Adding features for Nattu-Saraku.mp3 with label exuberance
# Processed file: Nattu-Saraku.mp3
# 61
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Arabic-Kuthu---Halamithi-Habibo.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Arabic-Kuthu---Halamithi-Habibo.mp3: torch.Size([22499, 1024])
# Adding features for Arabic-Kuthu---Halamithi-Habibo.mp3 with label exuberance
# Processed file: Arabic-Kuthu---Halamithi-Habibo.mp3
# 62
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Kozhi-Veda-Kozhi.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Kozhi-Veda-Kozhi.mp3: torch.Size([22499, 1024])
# Adding features for Kozhi-Veda-Kozhi.mp3 with label exuberance
# Processed file: Kozhi-Veda-Kozhi.mp3
# 63
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Intha Panchayathile.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Intha Panchayathile.mp3: torch.Size([22499, 1024])
# Adding features for Intha Panchayathile.mp3 with label exuberance
# Processed file: Intha Panchayathile.mp3
# 64
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Aaluma-Doluma.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Aaluma-Doluma.mp3: torch.Size([22499, 1024])
# Adding features for Aaluma-Doluma.mp3 with label exuberance
# Processed file: Aaluma-Doluma.mp3
# 65
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Merise Merise.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Merise Merise.mp3: torch.Size([22499, 1024])
# Adding features for Merise Merise.mp3 with label exuberance
# Processed file: Merise Merise.mp3
# 66
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Naa-Ready-MassTamilan.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Naa-Ready-MassTamilan.mp3: torch.Size([22499, 1024])
# Adding features for Naa-Ready-MassTamilan.mp3 with label exuberance
# Processed file: Naa-Ready-MassTamilan.mp3
# 67
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Jigelu Rani.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Jigelu Rani.mp3: torch.Size([22499, 1024])
# Adding features for Jigelu Rani.mp3 with label exuberance
# Processed file: Jigelu Rani.mp3
# 68
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Blockbuster.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Blockbuster.mp3: torch.Size([22499, 1024])
# Adding features for Blockbuster.mp3 with label exuberance
# Processed file: Blockbuster.mp3
# 69
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Maanja.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Maanja.mp3: torch.Size([22499, 1024])
# Adding features for Maanja.mp3 with label exuberance
# Processed file: Maanja.mp3
# 70
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Maanam Mannil.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Maanam Mannil.mp3: torch.Size([22499, 1024])
# Adding features for Maanam Mannil.mp3 with label exuberance
# Processed file: Maanam Mannil.mp3
# 71
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Kaatuka Kallu.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Kaatuka Kallu.mp3: torch.Size([22499, 1024])
# Adding features for Kaatuka Kallu.mp3 with label exuberance
# Processed file: Kaatuka Kallu.mp3
# 72
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Jai Balayya.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Jai Balayya.mp3: torch.Size([22499, 1024])
# Adding features for Jai Balayya.mp3 with label exuberance
# Processed file: Jai Balayya.mp3
# 73
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Dhavanipotta-Deepavali.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Dhavanipotta-Deepavali.mp3: torch.Size([22499, 1024])
# Adding features for Dhavanipotta-Deepavali.mp3 with label exuberance
# Processed file: Dhavanipotta-Deepavali.mp3
# 74
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Kakkothikkavile.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Kakkothikkavile.mp3: torch.Size([22499, 1024])
# Adding features for Kakkothikkavile.mp3 with label exuberance
# Processed file: Kakkothikkavile.mp3
# 75
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Ee Shishirakaalam _ Jacobinte Swargarajyam _ Nivin Pauly, Vineeth Sreenivasan, Shaan Rahman _.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Ee Shishirakaalam _ Jacobinte Swargarajyam _ Nivin Pauly, Vineeth Sreenivasan, Shaan Rahman _.mp3: torch.Size([22499, 1024])
# Adding features for Ee Shishirakaalam _ Jacobinte Swargarajyam _ Nivin Pauly, Vineeth Sreenivasan, Shaan Rahman _.mp3 with label exuberance
# Processed file: Ee Shishirakaalam _ Jacobinte Swargarajyam _ Nivin Pauly, Vineeth Sreenivasan, Shaan Rahman _.mp3
# 76
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Moham Kondal.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Moham Kondal.mp3: torch.Size([22499, 1024])
# Adding features for Moham Kondal.mp3 with label exuberance
# Processed file: Moham Kondal.mp3
# 77
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Aalaporan-Thamizhan-MassTamilan.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Aalaporan-Thamizhan-MassTamilan.mp3: torch.Size([22499, 1024])
# Adding features for Aalaporan-Thamizhan-MassTamilan.mp3 with label exuberance
# Processed file: Aalaporan-Thamizhan-MassTamilan.mp3
# 78
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Chellamma.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Chellamma.mp3: torch.Size([22499, 1024])
# Adding features for Chellamma.mp3 with label exuberance
# Processed file: Chellamma.mp3
# 79
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Gokulapaalapaalaka _ 1080p _ Paarthan Kanda Paralokam _ Jayaram _ Sona Heiden.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Gokulapaalapaalaka _ 1080p _ Paarthan Kanda Paralokam _ Jayaram _ Sona Heiden.mp3: torch.Size([22499, 1024])
# Adding features for Gokulapaalapaalaka _ 1080p _ Paarthan Kanda Paralokam _ Jayaram _ Sona Heiden.mp3 with label exuberance
# Processed file: Gokulapaalapaalaka _ 1080p _ Paarthan Kanda Paralokam _ Jayaram _ Sona Heiden.mp3
# 80
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Chocolate Poleyulloree.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Chocolate Poleyulloree.mp3: torch.Size([22499, 1024])
# Adding features for Chocolate Poleyulloree.mp3 with label exuberance
# Processed file: Chocolate Poleyulloree.mp3
# 81
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Jimikki Kammal.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Jimikki Kammal.mp3: torch.Size([22499, 1024])
# Adding features for Jimikki Kammal.mp3 with label exuberance
# Processed file: Jimikki Kammal.mp3
# 82
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Machi-Open-The-Bottle.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Machi-Open-The-Bottle.mp3: torch.Size([22499, 1024])
# Adding features for Machi-Open-The-Bottle.mp3 with label exuberance
# Processed file: Machi-Open-The-Bottle.mp3
# 83
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Nath Nath.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Nath Nath.mp3: torch.Size([22499, 1024])
# Adding features for Nath Nath.mp3 with label exuberance
# Processed file: Nath Nath.mp3
# 84
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Danga-Maari-Oodhari.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Danga-Maari-Oodhari.mp3: torch.Size([22499, 1024])
# Adding features for Danga-Maari-Oodhari.mp3 with label exuberance
# Processed file: Danga-Maari-Oodhari.mp3
# 85
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Bombhaat.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Bombhaat.mp3: torch.Size([22499, 1024])
# Adding features for Bombhaat.mp3 with label exuberance
# Processed file: Bombhaat.mp3
# 86
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Chirimanimulle.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Chirimanimulle.mp3: torch.Size([22499, 1024])
# Adding features for Chirimanimulle.mp3 with label exuberance
# Processed file: Chirimanimulle.mp3
# 87
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Kacheri-Kacheri.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Kacheri-Kacheri.mp3: torch.Size([22499, 1024])
# Adding features for Kacheri-Kacheri.mp3 with label exuberance
# Processed file: Kacheri-Kacheri.mp3
# 88
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Kalyana kacheri.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Kalyana kacheri.mp3: torch.Size([22499, 1024])
# Adding features for Kalyana kacheri.mp3 with label exuberance
# Processed file: Kalyana kacheri.mp3
# 89
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Andha-Arabi-Kadaloram.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Andha-Arabi-Kadaloram.mp3: torch.Size([22499, 1024])
# Adding features for Andha-Arabi-Kadaloram.mp3 with label exuberance
# Processed file: Andha-Arabi-Kadaloram.mp3
# 90
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Come To The Party.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Come To The Party.mp3: torch.Size([22499, 1024])
# Adding features for Come To The Party.mp3 with label exuberance
# Processed file: Come To The Party.mp3
# 91
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Marugo Marugo.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Marugo Marugo.mp3: torch.Size([22499, 1024])
# Adding features for Marugo Marugo.mp3 with label exuberance
# Processed file: Marugo Marugo.mp3
# 92
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Appangal Eambadum.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Appangal Eambadum.mp3: torch.Size([22499, 1024])
# Adding features for Appangal Eambadum.mp3 with label exuberance
# Processed file: Appangal Eambadum.mp3
# 93
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Gundellonaa.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Gundellonaa.mp3: torch.Size([22499, 1024])
# Adding features for Gundellonaa.mp3 with label exuberance
# Processed file: Gundellonaa.mp3
# 94
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Chandanamani.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Chandanamani.mp3: torch.Size([22499, 1024])
# Adding features for Chandanamani.mp3 with label exuberance
# Processed file: Chandanamani.mp3
# 95
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Ella-Pugazhum-MassTamilan.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Ella-Pugazhum-MassTamilan.mp3: torch.Size([22499, 1024])
# Adding features for Ella-Pugazhum-MassTamilan.mp3 with label exuberance
# Processed file: Ella-Pugazhum-MassTamilan.mp3
# 96
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Nakka-Mukka.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Nakka-Mukka.mp3: torch.Size([22499, 1024])
# Adding features for Nakka-Mukka.mp3 with label exuberance
# Processed file: Nakka-Mukka.mp3
# 97
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Karuppinazhaku.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Karuppinazhaku.mp3: torch.Size([22499, 1024])
# Adding features for Karuppinazhaku.mp3 with label exuberance
# Processed file: Karuppinazhaku.mp3
# 98
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/JILLAM JILLALA.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/JILLAM JILLALA.mp3: torch.Size([22499, 1024])
# Adding features for JILLAM JILLALA.mp3 with label exuberance
# Processed file: JILLAM JILLALA.mp3
# 99
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Kadamizhiyil Video Song 4K _ Rafi Mecartin _ Suresh Peters _ Suresh Gopi _ Lal.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Kadamizhiyil Video Song 4K _ Rafi Mecartin _ Suresh Peters _ Suresh Gopi _ Lal.mp3: torch.Size([22499, 1024])
# Adding features for Kadamizhiyil Video Song 4K _ Rafi Mecartin _ Suresh Peters _ Suresh Gopi _ Lal.mp3 with label exuberance
# Processed file: Kadamizhiyil Video Song 4K _ Rafi Mecartin _ Suresh Peters _ Suresh Gopi _ Lal.mp3
# 100
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Evo Evo Kalale.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Evo Evo Kalale.mp3: torch.Size([22499, 1024])
# Adding features for Evo Evo Kalale.mp3 with label exuberance
# Processed file: Evo Evo Kalale.mp3
# 101
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Damakku-Damakku-MassTamilan.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Damakku-Damakku-MassTamilan.mp3: torch.Size([22499, 1024])
# Adding features for Damakku-Damakku-MassTamilan.mp3 with label exuberance
# Processed file: Damakku-Damakku-MassTamilan.mp3
# 102
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Badass-MassTamilan.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Badass-MassTamilan.mp3: torch.Size([22499, 1024])
# Adding features for Badass-MassTamilan.mp3 with label exuberance
# Processed file: Badass-MassTamilan.mp3
# 103
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/4The People - Lajjavathiye song.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/4The People - Lajjavathiye song.mp3: torch.Size([22499, 1024])
# Adding features for 4The People - Lajjavathiye song.mp3 with label exuberance
# Processed file: 4The People - Lajjavathiye song.mp3
# 104
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Aattama Therottama.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Aattama Therottama.mp3: torch.Size([22499, 1024])
# Adding features for Aattama Therottama.mp3 with label exuberance
# Processed file: Aattama Therottama.mp3
# 105
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Life Ante Itta Vundaala.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/Life Ante Itta Vundaala.mp3: torch.Size([22499, 1024])
# Adding features for Life Ante Itta Vundaala.mp3 with label exuberance
# Processed file: Life Ante Itta Vundaala.mp3
# 106
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/College Papa.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/exuberance/College Papa.mp3: torch.Size([22499, 1024])
# Adding features for College Papa.mp3 with label exuberance
# Processed file: College Papa.mp3
# 107
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/exuberance/Neethoney Dance.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# ...
# Adding features for Vathilil.mp3 with label contentment
# Processed file: Vathilil.mp3
# 191
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/pachakkarikkaya_thattil.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/pachakkarikkaya_thattil.mp3: torch.Size([22499, 1024])
# Adding features for pachakkarikkaya_thattil.mp3 with label contentment
# Processed file: pachakkarikkaya_thattil.mp3
# 192
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/Kathirunna Pakshi.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/Kathirunna Pakshi.mp3: torch.Size([22499, 1024])
# Adding features for Kathirunna Pakshi.mp3 with label contentment
# Processed file: Kathirunna Pakshi.mp3
# 193
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/Saarattu-Vandiyila.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/Saarattu-Vandiyila.mp3: torch.Size([22499, 1024])
# Adding features for Saarattu-Vandiyila.mp3 with label contentment
# Processed file: Saarattu-Vandiyila.mp3
# 194
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/Sollamale-Yaar-Parthathu.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/Sollamale-Yaar-Parthathu.mp3: torch.Size([22499, 1024])
# Adding features for Sollamale-Yaar-Parthathu.mp3 with label contentment
# Processed file: Sollamale-Yaar-Parthathu.mp3
# 195
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/Evare.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/Evare.mp3: torch.Size([22499, 1024])
# Adding features for Evare.mp3 with label contentment
# Processed file: Evare.mp3
# 196
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/Manjal-Veiyil.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/Manjal-Veiyil.mp3: torch.Size([22499, 1024])
# Adding features for Manjal-Veiyil.mp3 with label contentment
# Processed file: Manjal-Veiyil.mp3
# 197
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/Agilam-Nee-MassTamilan.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/Agilam-Nee-MassTamilan.mp3: torch.Size([22499, 1024])
# Adding features for Agilam-Nee-MassTamilan.mp3 with label contentment
# Processed file: Agilam-Nee-MassTamilan.mp3
# 198
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/ILLIMULAM KADUKALIL.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/ILLIMULAM KADUKALIL.mp3: torch.Size([22499, 1024])
# Adding features for ILLIMULAM KADUKALIL.mp3 with label contentment
# Processed file: ILLIMULAM KADUKALIL.mp3
# 199
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/Maarivil.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/Maarivil.mp3: torch.Size([22499, 1024])
# Adding features for Maarivil.mp3 with label contentment
# Processed file: Maarivil.mp3
# 200
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/Choosa Choosa.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/Choosa Choosa.mp3: torch.Size([22499, 1024])
# Adding features for Choosa Choosa.mp3 with label contentment
# Processed file: Choosa Choosa.mp3
# 201
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/Manikkinavin.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/Manikkinavin.mp3: torch.Size([22499, 1024])
# Adding features for Manikkinavin.mp3 with label contentment
# Processed file: Manikkinavin.mp3
# 202
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/Mogathirai-Prelude-MassTamilan.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/Mogathirai-Prelude-MassTamilan.mp3: torch.Size([22499, 1024])
# Adding features for Mogathirai-Prelude-MassTamilan.mp3 with label contentment
# Processed file: Mogathirai-Prelude-MassTamilan.mp3
# 203
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/Veesum-Kaatrukku-MassTamilan.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/Veesum-Kaatrukku-MassTamilan.mp3: torch.Size([22499, 1024])
# Adding features for Veesum-Kaatrukku-MassTamilan.mp3 with label contentment
# Processed file: Veesum-Kaatrukku-MassTamilan.mp3
# 204
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/Gaaju Bomma.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/Gaaju Bomma.mp3: torch.Size([22499, 1024])
# Adding features for Gaaju Bomma.mp3 with label contentment
# Processed file: Gaaju Bomma.mp3
# 205
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/Illathe Kallyanathinu.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/Illathe Kallyanathinu.mp3: torch.Size([22499, 1024])
# Adding features for Illathe Kallyanathinu.mp3 with label contentment
# Processed file: Illathe Kallyanathinu.mp3
# 206
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/Thakita Thakajham.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/Thakita Thakajham.mp3: torch.Size([22499, 1024])
# Adding features for Thakita Thakajham.mp3 with label contentment
# Processed file: Thakita Thakajham.mp3
# 207
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/Ammaadi.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/Ammaadi.mp3: torch.Size([22499, 1024])
# Adding features for Ammaadi.mp3 with label contentment
# Processed file: Ammaadi.mp3
# 208
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/Kaarkuzhal-Kadavaiye-MassTamilan.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/Kaarkuzhal-Kadavaiye-MassTamilan.mp3: torch.Size([22499, 1024])
# Adding features for Kaarkuzhal-Kadavaiye-MassTamilan.mp3 with label contentment
# Processed file: Kaarkuzhal-Kadavaiye-MassTamilan.mp3
# 209
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/Marivillin Gopurangal.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/Marivillin Gopurangal.mp3: torch.Size([22499, 1024])
# Adding features for Marivillin Gopurangal.mp3 with label contentment
# Processed file: Marivillin Gopurangal.mp3
# 210
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/Poove Sempoove (Female).mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/Poove Sempoove (Female).mp3: torch.Size([22499, 1024])
# Adding features for Poove Sempoove (Female).mp3 with label contentment
# Processed file: Poove Sempoove (Female).mp3
# 211
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/theerame.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/theerame.mp3: torch.Size([22499, 1024])
# Adding features for theerame.mp3 with label contentment
# Processed file: theerame.mp3
# 212
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/Leharaayi.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/Leharaayi.mp3: torch.Size([22499, 1024])
# Adding features for Leharaayi.mp3 with label contentment
# Processed file: Leharaayi.mp3
# 213
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/Unakku-Thaan-MassTamilan.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/Unakku-Thaan-MassTamilan.mp3: torch.Size([22499, 1024])
# Adding features for Unakku-Thaan-MassTamilan.mp3 with label contentment
# Processed file: Unakku-Thaan-MassTamilan.mp3
# 214
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/En-Rojaa-Neeye-MassTamilan.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/En-Rojaa-Neeye-MassTamilan.mp3: torch.Size([22499, 1024])
# Adding features for En-Rojaa-Neeye-MassTamilan.mp3 with label contentment
# Processed file: En-Rojaa-Neeye-MassTamilan.mp3
# 215
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/Kayalinarike.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/Kayalinarike.mp3: torch.Size([22499, 1024])
# Adding features for Kayalinarike.mp3 with label contentment
# Processed file: Kayalinarike.mp3
# 216
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/Malare-Vijay-Yesudas.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/Malare-Vijay-Yesudas.mp3: torch.Size([22499, 1024])
# Adding features for Malare-Vijay-Yesudas.mp3 with label contentment
# Processed file: Malare-Vijay-Yesudas.mp3
# 217
# Resampling from 32000Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/Kadhal-Vaithu.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/Kadhal-Vaithu.mp3: torch.Size([22499, 1024])
# Adding features for Kadhal-Vaithu.mp3 with label contentment
# Processed file: Kadhal-Vaithu.mp3
# 218
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/Nenjodu-Cherthu-Aalaap-Raju.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/Nenjodu-Cherthu-Aalaap-Raju.mp3: torch.Size([22499, 1024])
# Adding features for Nenjodu-Cherthu-Aalaap-Raju.mp3 with label contentment
# Processed file: Nenjodu-Cherthu-Aalaap-Raju.mp3
# 219
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/Eeran Kaattin.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/Eeran Kaattin.mp3: torch.Size([22499, 1024])
# Adding features for Eeran Kaattin.mp3 with label contentment
# Processed file: Eeran Kaattin.mp3
# 220
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/Kalaya Nijama.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/Kalaya Nijama.mp3: torch.Size([22499, 1024])
# Adding features for Kalaya Nijama.mp3 with label contentment
# Processed file: Kalaya Nijama.mp3
# 221
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/Needhe Needhe.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/Needhe Needhe.mp3: torch.Size([22499, 1024])
# Adding features for Needhe Needhe.mp3 with label contentment
# Processed file: Needhe Needhe.mp3
# 222
# Resampling from 44100Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/Olathumbathirunnu.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/Olathumbathirunnu.mp3: torch.Size([22499, 1024])
# Adding features for Olathumbathirunnu.mp3 with label contentment
# Processed file: Olathumbathirunnu.mp3
# 223
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/Chamak Chamak Cham.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/Chamak Chamak Cham.mp3: torch.Size([22499, 1024])
# Adding features for Chamak Chamak Cham.mp3 with label contentment
# Processed file: Chamak Chamak Cham.mp3
# 224
# Resampling from 48000Hz to 24000Hz for ./sample_data/songs_mood_wise/contentment/Kotha Kothaga.mp3
# Adjusted waveform shape: torch.Size([1, 7200000])
# torch.Size([22499, 1024])
# torch.Size([30, 1024])
# Shape: (30, 1024)
# MERT features shape for ./sample_data/songs_mood_wise/contentment/Kotha Kothaga.mp3: torch.Size([22499, 1024])
# Adding features for Kotha Kothaga.mp3 with label contentment
# Processed file: Kotha Kothaga.mp3
# 225
# Final DataFrame:
#                                  mert_feature_vector  mood
# 0  [[0.03084738925099373, 0.07741767168045044, -0...   0.0
# 1  [[0.1873181313276291, 0.0030396468937397003, 0...   0.0
# 2  [[-0.06948937475681305, 0.11163745820522308, 0...   0.0
# 3  [[0.00949324481189251, 0.16176041960716248, -0...   0.0
# 4  [[-0.01119118370115757, -0.06787111610174179, ...   0.0
#                                    mert_feature_vector  mood
# 220  [[0.07388227432966232, 0.13893866539001465, 0....   3.0
# 221  [[-0.044564682990312576, 0.1350664347410202, -...   3.0
# 222  [[0.1709166318178177, 0.044728778302669525, 0....   3.0
# 223  [[-0.044116534292697906, 0.0356871634721756, 0...   3.0
# 224  [[0.0872235968708992, 0.20677673816680908, 0.0...   3.0
# Shape of the DataFrame: (225, 2)
# DataFrame saved as new CSV.
# DataFrame saved successfully.
